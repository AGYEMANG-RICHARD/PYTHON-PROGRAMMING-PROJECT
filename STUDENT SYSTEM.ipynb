# %%
#=================================
# STUDENT PROFILE SYSTEM
#=================================

#Input (all input() values are initially strings)
#str
name_input=input("Enter your full name: ")

#str-> int 
age_input=input("Enter your age: ")
age=int(age_input)

#str->float 
gpa_input=input("Enter your GPA: ")
gpa=float(gpa_input)

#str->list
courses_input=input("Enter courses enrolled (comma-separated): ")
courses=courses_input.split(",")

#bool 
deans_list=gpa>=3.47
is_minor=age<18

#dict
student_profile= {
    "name": name_input,
    "age": age,
    "courses":courses,
    "num_courses": len(courses)
}

#Show type conversions
print("\n==== TYPE CONVERSION ====")
print(f"Name Input Type: {type(name_input)}")
# ==================================
# STUDENT PROFILE SYSTEM
# ==================================

# Input (all input() values are initially strings)

# str
name_input = input("Enter your full name: ")

# str -> int
age_input = input("Enter your age: ")
age = int(age_input)

# str -> float
gpa_input = input("Enter your GPA: ")
gpa = float(gpa_input)

# str -> list
courses_input = input("Enter courses enrolled (comma-separated): ")
courses = courses_input.split(",")

# bool
deans_list = gpa >= 3.5
is_minor = age < 18

# dict
student_profile = {
    "name": name_input,
    "age": age,
    "gpa": gpa,
    "courses": courses,
    "num_courses": len(courses)
}

# Show type conversions
print("\n===== TYPE CONVERSION =====")
print(f"Name Input Type: {type(name_input)}")
print(f"Age Input Type: {type(age_input)}")
print(f"Converted Age Type: {type(age)}")
print(f"GPA Input Type: {type(gpa_input)}")
print(f"Converted GPA Type: {type(gpa)}")
print(f"Courses Input Type: {type(courses_input)}")
print(f"Converted Courses Type: {type(courses)}")
print(f"Dean's List Type: {type(deans_list)}")
print(f"Student Profile Type: {type(student_profile)}")

# Display student profile
print("\n===== STUDENT PROFILE =====")
print(f"Name:        {student_profile['name']}")

if is_minor:
    print(f"Age:         {student_profile['age']} (Minor)")
else:
    print(f"Age:         {student_profile['age']} (Adult)")

print(f"GPA:         {student_profile['gpa']}")
print(f"Courses:     {student_profile['courses']}")
print(f"# Courses:   {student_profile['num_courses']}")

if deans_list:
    print("Dean's List: Yes")
else:
    print("Dean's List: No")

print("===========================")
# Out:
# Enter your full name:  Richard Agyemang
# Enter your age:  22
# Enter your GPA:  3.52
# Enter courses enrolled (comma-separated):  Programming with python,Software Engineering,Object Oriented with Java
# ==== TYPE CONVERSION ====
# Name Input Type: <class 'str'>
# Enter your full name:  Richard Agyemang
# Enter your age:  22
# Enter your GPA:  3.52
# Enter courses enrolled (comma-separated):  Programming with python,Software Engineering,Object Oriented with Java
# ===== TYPE CONVERSION =====
# Name Input Type: <class 'str'>
# Age Input Type: <class 'str'>
# Converted Age Type: <class 'int'>
# GPA Input Type: <class 'str'>
# Converted GPA Type: <class 'float'>
# Courses Input Type: <class 'str'>
# Converted Courses Type: <class 'list'>
# Dean's List Type: <class 'bool'>
# Student Profile Type: <class 'dict'>
#
# ===== STUDENT PROFILE =====
# Name:        Richard Agyemang
# Age:         22 (Adult)
# GPA:         3.52
# ...
